# %%
import pandas as pd
import matplotlib as plt 
import seaborn as snb
import altair as alt

# %%
insurance_df = pd.read_csv('insurance2.csv', sep=',')
insurance_df
# Out:
#       age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0      19    0  27.900         0       1       3  16884.92400               1
# 1      18    1  33.770         1       0       2   1725.55230               1
# 2      28    1  33.000         3       0       2   4449.46200               0
# 3      33    1  22.705         0       0       1  21984.47061               0
# 4      32    1  28.880         0       0       1   3866.85520               1
# ...   ...  ...     ...       ...     ...     ...          ...             ...
# 1333   50    1  30.970         3       0       1  10600.54830               0
# 1334   18    0  31.920         0       0       0   2205.98080               1
# 1335   18    0  36.850         0       0       2   1629.83350               1
# 1336   21    0  25.800         0       0       3   2007.94500               0
# 1337   61    0  29.070         0       1       1  29141.36030               1
#
# [1338 rows x 8 columns]

# %% [markdown]
# ## 1-Quantos clientes são fumantes?

# %%
smokers_df = insurance_df['smoker'] == 1
smokers_df = insurance_df[smokers_df]
smokers_df
# Out:
#       age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0      19    0  27.900         0       1       3  16884.92400               1
# 11     62    0  26.290         0       1       2  27808.72510               1
# 14     27    1  42.130         0       1       2  39611.75770               1
# 19     30    1  35.300         0       1       3  36837.46700               1
# 23     34    0  31.920         1       1       0  37701.87680               1
# ...   ...  ...     ...       ...     ...     ...          ...             ...
# 1313   19    0  34.700         2       1       3  36397.57600               1
# 1314   30    0  23.655         3       1       1  18765.87545               0
# 1321   62    1  26.695         0       1       0  28101.33305               1
# 1323   42    0  40.370         2       1       2  43896.37630               1
# 1337   61    0  29.070         0       1       1  29141.36030               1
#
# [274 rows x 8 columns]

# %% [markdown]
# ## 2-Quantos fumantes por região?

# %%
smkr_chart = pd.DataFrame(columns=['regiaoao'])

# %%
smoker_reg = smokers_df.groupby('region', as_index = False).count()[['region', 'smoker']]
smoker_reg['Nome Regiao'] = smoker_reg['region'].apply(
    lambda x: 'Nordeste' if x == 0 else ('Noroeste' if x == 1 else( 'Sudeste' if x == 2 else 'Sudoeste'))  
)
smoker_reg
# Out:
#    region  smoker Nome Regiao
# 0       0      67    Nordeste
# 1       1      58    Noroeste
# 2       2      91     Sudeste
# 3       3      58    Sudoeste

# %%
alt.Chart(smoker_reg, title="Quantidade de fumantes por região").mark_bar().encode(
    x = alt.X('Nome Regiao', title="Região"),
    y = alt.Y('smoker', title="Fumantes"),
    color = alt.Color('region')
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 3-Histograma das Idades

# %%
idade_df =  insurance_df['age']
idade_df.hist()

# %% [markdown]
# ## 4-Relação idade custo

# %%
c_id_df = insurance_df.groupby('age').sum()
c_id_df
# Out:
#      sex       bmi  children  smoker  region        charges  insuranceclaim
# age
# 18    36  2161.505        31      12      74  488949.011389              46
# 19    35  1944.590        29      18     133  662857.834750              40
# 20    15   888.350        25       9      47  294631.234350              23
# 21    15   789.200        22       2      42  132453.001230              16
# 22    15   870.455        20       6      41  280362.118450              19
# 23    14   880.725        28       7      42  347754.961110              17
# 24    14   815.995        13       6      42  298144.446940              16
# 25    15   831.430        36       5      42  275474.228700              15
# 26    15   824.010        30       3      42  171747.108640              11
# 27    14   821.340        27       9      42  341171.648200              15
# 28    14   825.500        36       3      43  253937.251800              10
# 29    14   793.345        34       6      39  281614.285630              11
# 30    14   825.055        42       9      43  343415.979670              10
# 31    14   807.795        38       5      39  275318.475480               9
# 32    13   821.540        33       5      41  239727.807560              12
# 33    13   810.240        40       6      43  321139.857670               9
# 34    13   787.125        30       5      39  301951.731140              12
# 35    13   784.870        42       5      39  282679.550780               6
# 36    13   734.355        31       6      35  305111.903450              13
# 37    13   780.415        38       9      37  450497.796930              16
# 38    12   724.915        37       2      38  202568.341850               7
# 39    12   747.755        55       6      39  294456.073630               9
# 40    14   813.755        43       5      38  317850.785370              10
# 41    14   850.685        38       2      41  260651.132540              14
# 42    14   818.860        27       8      43  352648.044060              20
# 43    13   815.520        44      12      42  520216.523640              19
# 44    13   832.795        33       6      41  428203.707850              18
# 45    15   863.590        43       5      45  430075.795830              20
# 46    15   908.885        47       5      42  415935.128520              17
# 47    14   889.265        40      10      45  511965.988200              21
# 48    14   925.845        38       5      43  424342.512910              19
# 49    14   848.790        42       4      42  355488.175400              14
# 50    15   902.835        38       4      45  454227.095720              19
# 51    14   920.085        32       6      45  454785.420150              19
# 52    14   955.145        43       6      43  529431.821860              21
# 53    14   850.105        35       5      42  448586.061140              21
# 54    14   874.560        40       5      42  525239.301310              17
# 55    13   830.700        25       2      41  420278.182700              18
# 56    13   821.625        20       4      39  390663.411750              17
# 57    13   801.955        16       4      37  427626.816500              18
# 58    12   817.955         6       1      37  346973.202790              20
# 59    12   764.300        30       4      39  472396.738290              17
# 60    12   697.655         8       5      35  505526.625670              14
# 61    11   748.610        17       6      34  506562.525000              16
# 62    11   743.880        13       4      33  440768.701190              18
# 63    11   734.240        13       5      36  457354.964600              16
# 64    11   725.475        17       7      36  512061.678420              18
